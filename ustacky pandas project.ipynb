# %% [markdown]
# # Loading Dataset

# %%
#importing the required libraries
import os
import glob
import pandas as pd
os.chdir(r"C:/Users/Admin/Desktop/DS_DA project/Pandas-Analytics-Project-main")

# %%
#adding the appropriate extension and storing in the desired location
extension = 'csv'
files = glob.glob(r"C:/Users/Admin/Desktop/DS_DA project/Pandas-Analytics-Project-main/*.csv")

# %%
#save in a dataframe
frame = []
for file in files:
    frame.append(pd.read_csv(file))
df = pd.concat(frame)

# %%
#view the dataframe
df
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    692-92-5582      B          Abuja        Member  Female
# 1    351-62-0822      B          Abuja        Member  Female
# 2    529-56-3974      B          Abuja        Member    Male
# 3    299-46-1805      B          Abuja        Member  Female
# 4    319-50-3348      B          Abuja        Normal  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0        Food and beverages     19742.4         3   2961.36   62188.56
# 1       Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Exploration

# %%
#view dataframe head
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
#check number of rows and columns in dataframe
df.shape
# Out:
# (1000, 17)

# %%
#check dataframe titles
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#brief summary of dataframe values
df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# ...

# %% [markdown]
# FINDINGS
# - The maximum unit price is 35985.60 while the minimum is 3628.8
# - The maximum quantiy of goods sold is 10 while the minimum is 1
# - The maxiximum tax collected is 17874 while the minimum is 3844.26

# %%
#check missing values in dataframe
print(df.isnull().sum().sum())
# Out:
# 0

# %%
#brief info on datatypes, column names and entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 327
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# # Dealing with DateTime Features

# %%
# Convert 'Date' column datatype from str to datetime 
df['Date'] = pd.to_datetime(df['Date'])

# %%
#confirm change to datetime
print(df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
#conversion of Time column to datetime
df['Time'] = pd.to_datetime(df['Time'])

# %%
#confirm change to datetime
print(df['Time'].dtype)
# Out:
# datetime64[ns]

# %%
#extracting the days of the months of transcation
df['Day'] = df.Date.dt.day
df['Day']
# Out:
# 0      20
# 1       6
# 2       9
# 3      15
# 4      11
#        ..
# 323    23
# 324     9
# 325    29
# 326    18
# 327    29
# Name: Day, Length: 1000, dtype: int64

# %%
#extracting the months of transcation
df['Month'] = df.Date.dt.month
df['Month']
# Out:
# 0      2
# 1      2
# 2      3
# 3      1
# 4      3
#       ..
# 323    1
# 324    1
# 325    3
# 326    2
# 327    1
# Name: Month, Length: 1000, dtype: int64

# %%
#extracting the year of transaction
df['Year'] = df.Date.dt.year
df['Year']
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 323    2019
# 324    2019
# 325    2019
# 326    2019
# 327    2019
# Name: Year, Length: 1000, dtype: int64

# %%
#extracting the hour of transaction
df['Hour'] = df.Time.dt.hour
df['Hour']
# Out:
# 0      13
# 1      18
# 2      17
# 3      16
# 4      15
#        ..
# 323    10
# 324    11
# 325    19
# 326    11
# 327    13
# Name: Hour, Length: 1000, dtype: int64

# %%
#number of unique hours of transaction
df['Hour'].nunique()
# Out:
# 11

# %%
#array of unique hour sales
df['Hour'].unique()
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20], dtype=int64)

# %% [markdown]
# # Unique Values in Columns

# %%
#getting the categorical columns
categorical_columns=[]
for col in df.columns:
    if df[col].dtype == "object":
        categorical_columns.append(col)
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %%
#alternatively
categorical_columns = [col for col in df.columns if df[col].dtype == "object" ]
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %%
ii = df['Invoice ID'].unique().tolist()
print(ii)
# Out:
# ['692-92-5582', '351-62-0822', '529-56-3974', '299-46-1805', '319-50-3348', '371-85-5789', '273-16-6619', '649-29-6775', '145-94-9061', '871-79-8483', '149-71-6266', '640-49-2076', '777-82-7220', '280-35-5823', '354-25-5821', '132-32-9879', '370-41-7321', '727-46-3608', '669-54-1719', '616-24-2851', '242-55-6721', '347-34-2234', '853-23-2453', '109-28-2512', '510-95-6347', '847-38-7188', '318-68-5053', '152-08-9985', '766-85-7061', '733-01-9107', '716-39-1409', '479-26-8945', '227-78-1148', '291-32-1427', '659-65-8956', '378-24-2715', '219-22-9386', '268-27-6179', '549-84-7482', '191-10-6171', '695-51-0018', '590-83-4591', '241-72-9525', '262-47-2794', '608-96-3517', '279-74-2924', '307-85-2293', '743-04-1105', '423-57-2993', '548-46-9322', '505-02-0892', '316-55-4634', '608-27-6295', '414-12-7047', '895-66-0685', '305-14-0245', '732-04-5373', '284-34-9626', '437-58-8131', '641-43-2399', '542-41-0513', '875-46-5808', '394-43-4238', '573-58-9734', '817-69-8206', '142-63-6033', '656-16
# ...

# %%
print("Total Number of unique values in the Invoice ID Column : {}". format(len(ii)))
# Out:
# Total Number of unique values in the Invoice ID Column : 1000

# %%
#number of entries in each city
df['City'].value_counts()
# Out:
# Lagos            340
# Abuja            332
# Port Harcourt    328
# Name: City, dtype: int64

# %%
#number of each customer type
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
#Number of products type consumed
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [markdown]
# # Aggregation with GroupBy

# %%
#groupby city column on mean
df.groupby("City").mean()
# Out:
#                  Unit price  Quantity       Tax 5%          Total  \
# City
# Abuja          20037.339759  5.481928  5483.528675  115154.102169
# Lagos          19721.107059  5.467647  5354.640529  112447.451118
# Port Harcourt  20379.248780  5.582317  5778.852256  121355.897378
#
#                         cogs  gross margin percentage  gross income    Rating  \
# City
# Abuja          109670.573494                 4.761905   5483.528675  6.818072
# Lagos          107092.810588                 4.761905   5354.640529  7.027059
# Port Harcourt  115577.045122                 4.761905   5778.852256  7.072866
#
#                      Day     Month    Year       Hour
# City
# Abuja          15.265060  2.003012  2019.0  15.147590
# Lagos          15.388235  2.023529  2019.0  14.667647
# Port Harcourt  15.109756  1.951220  2019.0  14.920732

# %%
#groupby city column on mean
df.groupby("City").sum()
# Out:
#                Unit price  Quantity      Tax 5%        Total        cogs  \
# City
# Abuja           6652396.8      1820  1820531.52  38231161.92  36410630.4
# Lagos           6705176.4      1859  1820577.78  38232133.38  36411555.6
# Port Harcourt   6684393.6      1831  1895463.54  39804734.34  37909270.8
#
#                gross margin percentage  gross income  Rating   Day  Month  \
# City
# Abuja                      1580.952381    1820531.52  2263.6  5068    665
# Lagos                      1619.047619    1820577.78  2389.2  5232    688
# Port Harcourt              1561.904762    1895463.54  2319.9  4956    640
#
#                  Year  Hour
# City
# Abuja          670308  5029
# Lagos          686460  4987
# Port Harcourt  662232  4894

# %%
#gross income of each city
city_gross=df.groupby("City")['gross income'].sum()
city_gross
# Out:
# City
# Abuja            1820531.52
# Lagos            1820577.78
# Port Harcourt    1895463.54
# Name: gross income, dtype: float64

# %%
#The city with the maximum gross income
for i in city_gross:
    if i == city_gross.max():
        print('The city with the maximum gross income is:',city_gross.idxmax())
# Out:
# The city with the maximum gross income is: Port Harcourt

# %% [markdown]
# # Data Visualization

# %%
#Visualization of branches with the highest sales record
sns.countplot(x ='Branch', data = df).set_title('The branch with the highest sales record');

# %%
#Most used payment method
sns.countplot(x ='Payment', data = df).set_title('The most used payment method');

# %%
#The city with most sales
sns.countplot(x ='City', data = df).set_title('The city with most sales');

# %%
#Product line and their number across the cities
sns.countplot(y ='Product line', data = df).set_title('The Product line plot');

# %%
#count of product line across the cities
df.groupby("Product line")['City'].count()
# Out:
# Product line
# Electronic accessories    170
# Fashion accessories       178
# Food and beverages        174
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# Name: City, dtype: int64

# %%
#The Product line comsumption per city
sns.countplot(y ='Product line',hue='City', data = df).set_title('The Product line comsumption per city');

# %%
#The payment method used for each Product line
sns.countplot(y ='Product line',hue='Payment', data = df).set_title('The payment method used for each Product line');

# %%
#The payment method used for each Branch
sns.countplot(x ='Payment',hue='Branch', data = df).set_title('The payment method used for each Branch');

# %%
#boxplot for each branch ratings
sns.boxplot(x='Branch', y='Rating', data=df).set_title('Branch Ratings');

# %%
#catplot for each product line and quantity purchased by each gender
sns.catplot(x='Product line', y='Quantity',hue='Gender', data=df, aspect=5);

# %%
#catplot for each product line and the total quantity purchased by each gender
sns.catplot(x='Product line', y='Total',hue='Gender', data=df, aspect=4);

# %%
#catplot for each product line and unit price for items purchased by each gender
sns.catplot(x='Product line', y='Unit price', data=df, aspect=4, kind='point',hue='Gender');

# %%
#catplot for each product line and quantity purchased by each gender
sns.catplot(x='Product line', y='Quantity', data=df, aspect=4, kind='point',hue='Gender');
